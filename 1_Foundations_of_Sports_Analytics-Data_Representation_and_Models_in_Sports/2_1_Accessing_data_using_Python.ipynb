# %% [markdown]
# <a href="https://colab.research.google.com/github/epifeni/Sports-Performance-Analytics-Specialization/blob/main/2_1_Accessing_data_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Basketball data downloaded from NBA.com
#
# _In this week, we will use basketball data downloaded from NBA.com to demonstrate how to import data into Python, how to clean up data before conducting any data analyses, as well how to describe and summarize data._
#
# ## Importing data into Python
# ### Before we import the dataset into Jupyter notebook, we need to first import the Python libraries that we will use to analyze the data
# - pandas
# - numpy

# %%
import pandas as pd
import numpy as np

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### In our data repository, we have a dataset that contains NBA team information. Let's import this dataset into the Jupyter notebook.

# %%
NBA_Teams=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Sports Performance Analytics Specialization/Course 1 - Foundations of Sports Analytics: Data, Representation, and Models in Sports/work/Data/Week 2/nba_teams.csv")

# %% [markdown]
# We can take a quick look at the data we imported by displaying the dataset.

# %%
display(NBA_Teams)
# Out:
#     Unnamed: 0 ABBREVIATION           CITY               FULL_NAME  \
# 0            0          ATL        Atlanta           Atlanta Hawks
# 1            1          BOS         Boston          Boston Celtics
# 2            2          CLE      Cleveland     Cleveland Cavaliers
# 3            3          NOP    New Orleans    New Orleans Pelicans
# 4            4          CHI        Chicago           Chicago Bulls
# 5            5          DAL         Dallas        Dallas Mavericks
# 6            6          DEN         Denver          Denver Nuggets
# 7            7          GSW   Golden State   Golden State Warriors
# 8            8          HOU        Houston         Houston Rockets
# 9            9          LAC    Los Angeles    Los Angeles Clippers
# 10          10          LAL    Los Angeles      Los Angeles Lakers
# 11          11          MIA          Miami              Miami Heat
# 12          12          MIL      Milwaukee         Milwaukee Bucks
# 13          13          MIN      Minnesota  Minnesota Timberwolves
# 14          14          BKN       Brooklyn           Brooklyn Nets
# 15          15          NYK       New York         New York Knicks
# 16          16          ORL        Orlando           Orlando Magic
# 17          17          IND        Indiana          Indiana Pacers
# 18          18          PHI   Philadelphia      Philadelphia 76ers
# 19          19          PHX        Phoenix            Phoenix Suns
# 20          20          POR       Portland  Portland Trail Blazers
# 21          21          SAC     Sacramento        Sacramento Kings
# 22          22          SAS    San Antonio       San Antonio Spurs
# 23          23          OKC  Oklahoma City   Oklahoma City Thunder
# 24          24          TOR        Toronto         Toronto Raptors
# 25          25          UTA           Utah               Utah Jazz
# 26          26          MEM        Memphis       Memphis Grizzlies
# 27          27          WAS     Washington      Washington Wizards
# 28          28          DET        Detroit         Detroit Pistons
# 29          29          CHA      Charlotte       Charlotte Hornets
#
#             ID       NICKNAME                 STATE  YEAR_FOUNDED
# 0   1610612737          Hawks               Atlanta          1949
# 1   1610612738        Celtics         Massachusetts          1946
# 2   1610612739      Cavaliers                  Ohio          1970
# 3   1610612740       Pelicans             Louisiana          2002
# 4   1610612741          Bulls              Illinois          1966
# 5   1610612742      Mavericks                 Texas          1980
# 6   1610612743        Nuggets              Colorado          1976
# 7   1610612744       Warriors            California          1946
# 8   1610612745        Rockets                 Texas          1967
# 9   1610612746       Clippers            California          1970
# 10  1610612747         Lakers            California          1948
# 11  1610612748           Heat               Florida          1988
# 12  1610612749          Bucks             Wisconsin          1968
# 13  1610612750   Timberwolves             Minnesota          1989
# 14  1610612751           Nets              New York          1976
# 15  1610612752         Knicks              New York          1946
# 16  1610612753          Magic               Florida          1989
# 17  1610612754         Pacers               Indiana          1976
# 18  1610612755          76ers          Pennsylvania          1949
# 19  1610612756           Suns               Arizona          1968
# 20  1610612757  Trail Blazers                Oregon          1970
# 21  1610612758          Kings            California          1948
# 22  1610612759          Spurs                 Texas          1976
# 23  1610612760        Thunder              Oklahoma          1967
# 24  1610612761        Raptors               Ontario          1995
# 25  1610612762           Jazz                  Utah          1974
# 26  1610612763      Grizzlies             Tennessee          1995
# 27  1610612764        Wizards  District of Columbia          1961
# 28  1610612765        Pistons              Michigan          1948
# 29  1610612766        Hornets        North Carolina          1988

# %% [markdown]
# _This dataset provides some basic information of the NBA teams._
#
# For a dataset, each row represents an observation, i.e., a team in this dataset and each column represents a variable which contains information of a characteristics of the observation. A variable can take different values in different situations. The number of observation in a dataset represents the size of our sample and the number of variables represents the richness of information in our dataset.
#
# #### We can use the “shape” function in Python to see how many variables and observations in our dataset.

# %%
NBA_Teams.shape
# Out:
# (30, 8)

# %% [markdown]
# _We can see that there are 30 observations (rows) and 8 variables (columns)._
#
# ### Renaming Variables
# ####  We can rename a variable using the “rename” function in Python.
# _Inplace parameter_
# - True: replace the old variable with a new name;
# - False: create a new variable with the new name.
#
# The first variable is unnamed, let's rename it to be "TEAM_NUMBER"; let's also rename "ID" to "TEAM_ID."

# %%
NBA_Teams.rename(columns={'Unnamed: 0':'TEAM_NUMBER'}, inplace=True)

NBA_Teams.rename(columns={'ID':'TEAM_ID'}, inplace=True)
display(NBA_Teams)
# Out:
#     TEAM_NUMBER ABBREVIATION           CITY               FULL_NAME  \
# 0             0          ATL        Atlanta           Atlanta Hawks
# 1             1          BOS         Boston          Boston Celtics
# 2             2          CLE      Cleveland     Cleveland Cavaliers
# 3             3          NOP    New Orleans    New Orleans Pelicans
# 4             4          CHI        Chicago           Chicago Bulls
# 5             5          DAL         Dallas        Dallas Mavericks
# 6             6          DEN         Denver          Denver Nuggets
# 7             7          GSW   Golden State   Golden State Warriors
# 8             8          HOU        Houston         Houston Rockets
# 9             9          LAC    Los Angeles    Los Angeles Clippers
# 10           10          LAL    Los Angeles      Los Angeles Lakers
# 11           11          MIA          Miami              Miami Heat
# 12           12          MIL      Milwaukee         Milwaukee Bucks
# 13           13          MIN      Minnesota  Minnesota Timberwolves
# 14           14          BKN       Brooklyn           Brooklyn Nets
# 15           15          NYK       New York         New York Knicks
# 16           16          ORL        Orlando           Orlando Magic
# 17           17          IND        Indiana          Indiana Pacers
# 18           18          PHI   Philadelphia      Philadelphia 76ers
# 19           19          PHX        Phoenix            Phoenix Suns
# 20           20          POR       Portland  Portland Trail Blazers
# 21           21          SAC     Sacramento        Sacramento Kings
# 22           22          SAS    San Antonio       San Antonio Spurs
# 23           23          OKC  Oklahoma City   Oklahoma City Thunder
# 24           24          TOR        Toronto         Toronto Raptors
# 25           25          UTA           Utah               Utah Jazz
# 26           26          MEM        Memphis       Memphis Grizzlies
# 27           27          WAS     Washington      Washington Wizards
# 28           28          DET        Detroit         Detroit Pistons
# 29           29          CHA      Charlotte       Charlotte Hornets
#
#        TEAM_ID       NICKNAME                 STATE  YEAR_FOUNDED
# 0   1610612737          Hawks               Atlanta          1949
# 1   1610612738        Celtics         Massachusetts          1946
# 2   1610612739      Cavaliers                  Ohio          1970
# 3   1610612740       Pelicans             Louisiana          2002
# 4   1610612741          Bulls              Illinois          1966
# 5   1610612742      Mavericks                 Texas          1980
# 6   1610612743        Nuggets              Colorado          1976
# 7   1610612744       Warriors            California          1946
# 8   1610612745        Rockets                 Texas          1967
# 9   1610612746       Clippers            California          1970
# 10  1610612747         Lakers            California          1948
# 11  1610612748           Heat               Florida          1988
# 12  1610612749          Bucks             Wisconsin          1968
# 13  1610612750   Timberwolves             Minnesota          1989
# 14  1610612751           Nets              New York          1976
# 15  1610612752         Knicks              New York          1946
# 16  1610612753          Magic               Florida          1989
# 17  1610612754         Pacers               Indiana          1976
# 18  1610612755          76ers          Pennsylvania          1949
# 19  1610612756           Suns               Arizona          1968
# 20  1610612757  Trail Blazers                Oregon          1970
# 21  1610612758          Kings            California          1948
# 22  1610612759          Spurs                 Texas          1976
# 23  1610612760        Thunder              Oklahoma          1967
# 24  1610612761        Raptors               Ontario          1995
# 25  1610612762           Jazz                  Utah          1974
# 26  1610612763      Grizzlies             Tennessee          1995
# 27  1610612764        Wizards  District of Columbia          1961
# 28  1610612765        Pistons              Michigan          1948
# 29  1610612766        Hornets        North Carolina          1988

# %% [markdown]
# ## Self Test - 1
# - Rename "FULL_NAME" to "TEAM_NAME"

# %%
NBA_Teams.rename(columns={'FULL_NAME':'TEAM_NAME'}, inplace=True)
display(NBA_Teams)
# Out:
#     TEAM_NUMBER ABBREVIATION           CITY               TEAM_NAME  \
# 0             0          ATL        Atlanta           Atlanta Hawks
# 1             1          BOS         Boston          Boston Celtics
# 2             2          CLE      Cleveland     Cleveland Cavaliers
# 3             3          NOP    New Orleans    New Orleans Pelicans
# 4             4          CHI        Chicago           Chicago Bulls
# 5             5          DAL         Dallas        Dallas Mavericks
# 6             6          DEN         Denver          Denver Nuggets
# 7             7          GSW   Golden State   Golden State Warriors
# 8             8          HOU        Houston         Houston Rockets
# 9             9          LAC    Los Angeles    Los Angeles Clippers
# 10           10          LAL    Los Angeles      Los Angeles Lakers
# 11           11          MIA          Miami              Miami Heat
# 12           12          MIL      Milwaukee         Milwaukee Bucks
# 13           13          MIN      Minnesota  Minnesota Timberwolves
# 14           14          BKN       Brooklyn           Brooklyn Nets
# 15           15          NYK       New York         New York Knicks
# 16           16          ORL        Orlando           Orlando Magic
# 17           17          IND        Indiana          Indiana Pacers
# 18           18          PHI   Philadelphia      Philadelphia 76ers
# 19           19          PHX        Phoenix            Phoenix Suns
# 20           20          POR       Portland  Portland Trail Blazers
# 21           21          SAC     Sacramento        Sacramento Kings
# 22           22          SAS    San Antonio       San Antonio Spurs
# 23           23          OKC  Oklahoma City   Oklahoma City Thunder
# 24           24          TOR        Toronto         Toronto Raptors
# 25           25          UTA           Utah               Utah Jazz
# 26           26          MEM        Memphis       Memphis Grizzlies
# 27           27          WAS     Washington      Washington Wizards
# 28           28          DET        Detroit         Detroit Pistons
# 29           29          CHA      Charlotte       Charlotte Hornets
#
#        TEAM_ID       NICKNAME                 STATE  YEAR_FOUNDED
# 0   1610612737          Hawks               Atlanta          1949
# 1   1610612738        Celtics         Massachusetts          1946
# 2   1610612739      Cavaliers                  Ohio          1970
# 3   1610612740       Pelicans             Louisiana          2002
# 4   1610612741          Bulls              Illinois          1966
# 5   1610612742      Mavericks                 Texas          1980
# 6   1610612743        Nuggets              Colorado          1976
# 7   1610612744       Warriors            California          1946
# 8   1610612745        Rockets                 Texas          1967
# 9   1610612746       Clippers            California          1970
# 10  1610612747         Lakers            California          1948
# 11  1610612748           Heat               Florida          1988
# 12  1610612749          Bucks             Wisconsin          1968
# 13  1610612750   Timberwolves             Minnesota          1989
# 14  1610612751           Nets              New York          1976
# 15  1610612752         Knicks              New York          1946
# 16  1610612753          Magic               Florida          1989
# 17  1610612754         Pacers               Indiana          1976
# 18  1610612755          76ers          Pennsylvania          1949
# 19  1610612756           Suns               Arizona          1968
# 20  1610612757  Trail Blazers                Oregon          1970
# 21  1610612758          Kings            California          1948
# 22  1610612759          Spurs                 Texas          1976
# 23  1610612760        Thunder              Oklahoma          1967
# 24  1610612761        Raptors               Ontario          1995
# 25  1610612762           Jazz                  Utah          1974
# 26  1610612763      Grizzlies             Tennessee          1995
# 27  1610612764        Wizards  District of Columbia          1961
# 28  1610612765        Pistons              Michigan          1948
# 29  1610612766        Hornets        North Carolina          1988

# %% [markdown]
# ### Dropping Variables (columns)
#
# #### To drop a variable, i.e., to delete a column, we can use the “drop” command.
# - We need to provide the name of the variable;
# - We also need to use the argument “axis=1” which tells Python that we are dropping a column, not a row.
#
# The variable "TEAM_NUMBER" has little meaning, let's drop it.

# %%
NBA_Teams.drop(['TEAM_NUMBER'], axis=1, inplace=True)
display(NBA_Teams)
# Out:
#    ABBREVIATION           CITY               TEAM_NAME     TEAM_ID  \
# 0           ATL        Atlanta           Atlanta Hawks  1610612737
# 1           BOS         Boston          Boston Celtics  1610612738
# 2           CLE      Cleveland     Cleveland Cavaliers  1610612739
# 3           NOP    New Orleans    New Orleans Pelicans  1610612740
# 4           CHI        Chicago           Chicago Bulls  1610612741
# 5           DAL         Dallas        Dallas Mavericks  1610612742
# 6           DEN         Denver          Denver Nuggets  1610612743
# 7           GSW   Golden State   Golden State Warriors  1610612744
# 8           HOU        Houston         Houston Rockets  1610612745
# 9           LAC    Los Angeles    Los Angeles Clippers  1610612746
# 10          LAL    Los Angeles      Los Angeles Lakers  1610612747
# 11          MIA          Miami              Miami Heat  1610612748
# 12          MIL      Milwaukee         Milwaukee Bucks  1610612749
# 13          MIN      Minnesota  Minnesota Timberwolves  1610612750
# 14          BKN       Brooklyn           Brooklyn Nets  1610612751
# 15          NYK       New York         New York Knicks  1610612752
# 16          ORL        Orlando           Orlando Magic  1610612753
# 17          IND        Indiana          Indiana Pacers  1610612754
# 18          PHI   Philadelphia      Philadelphia 76ers  1610612755
# 19          PHX        Phoenix            Phoenix Suns  1610612756
# 20          POR       Portland  Portland Trail Blazers  1610612757
# 21          SAC     Sacramento        Sacramento Kings  1610612758
# 22          SAS    San Antonio       San Antonio Spurs  1610612759
# 23          OKC  Oklahoma City   Oklahoma City Thunder  1610612760
# 24          TOR        Toronto         Toronto Raptors  1610612761
# 25          UTA           Utah               Utah Jazz  1610612762
# 26          MEM        Memphis       Memphis Grizzlies  1610612763
# 27          WAS     Washington      Washington Wizards  1610612764
# 28          DET        Detroit         Detroit Pistons  1610612765
# 29          CHA      Charlotte       Charlotte Hornets  1610612766
#
#          NICKNAME                 STATE  YEAR_FOUNDED
# 0           Hawks               Atlanta          1949
# 1         Celtics         Massachusetts          1946
# 2       Cavaliers                  Ohio          1970
# 3        Pelicans             Louisiana          2002
# 4           Bulls              Illinois          1966
# 5       Mavericks                 Texas          1980
# 6         Nuggets              Colorado          1976
# 7        Warriors            California          1946
# 8         Rockets                 Texas          1967
# 9        Clippers            California          1970
# 10         Lakers            California          1948
# 11           Heat               Florida          1988
# 12          Bucks             Wisconsin          1968
# 13   Timberwolves             Minnesota          1989
# 14           Nets              New York          1976
# 15         Knicks              New York          1946
# 16          Magic               Florida          1989
# 17         Pacers               Indiana          1976
# 18          76ers          Pennsylvania          1949
# 19           Suns               Arizona          1968
# 20  Trail Blazers                Oregon          1970
# 21          Kings            California          1948
# 22          Spurs                 Texas          1976
# 23        Thunder              Oklahoma          1967
# 24        Raptors               Ontario          1995
# 25           Jazz                  Utah          1974
# 26      Grizzlies             Tennessee          1995
# 27        Wizards  District of Columbia          1961
# 28        Pistons              Michigan          1948
# 29        Hornets        North Carolina          1988

# %% [markdown]
# #### Next we will work on game level data.
#
# Import the game level dataset from our data repository.
# - We can display just first five rows of the dataset using the "head" command.

# %%
Games=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Sports Performance Analytics Specialization/Course 1 - Foundations of Sports Analytics: Data, Representation, and Models in Sports/work/Data/Week 2/basketball_games.csv")
Games.head()
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 0      22019  1611661322               WAS  Washington Mystics  1021900079
# 1      22019  1611661319               LVA      Las Vegas Aces  1021900079
# 2      22019  1611661320               LAS  Los Angeles Sparks  1021900124
# 3      22019  1611661323               CON     Connecticut Sun  1021900122
# 4      22019  1611661317               PHO     Phoenix Mercury  1021900122
#
#   GAME_DATE      MATCHUP   WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  8/5/2019    WAS @ LVA  NaN  101   51  ...   0.750     3    10   13   14
# 1  8/5/2019  LVA vs. WAS  NaN  100   36  ...   0.800     5    10   15   12
# 2  8/1/2019  LAS vs. LVA    W  200   76  ...   1.000     5    28   33   19
# 3  8/1/2019  CON vs. PHO    W  200   68  ...   0.786    12    28   40   18
# 4  8/1/2019    PHO @ CON    L  199   62  ...   0.778     6    23   29   15
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    2    4    5   7        12.2
# 1    2    0    7   8       -11.8
# 2    7    7   12  18         8.0
# 3   13    0   16  15         6.0
# 4    8    9   18  11        -6.0
#
# [5 rows x 28 columns]

# %% [markdown]
# _Upon importing the game data, we notice that the first five games are not NBA games, instead, they are WNBA games. Indeed, this dataset contains NBA games, WNBA games, NBA 2K (simulation video) games._
#
# ### Dropping observations (rows)
#
# #### To drop an observation, we can use the index number on the left to specify the row we want to drop.
# - The argument axis=0 specifies that we want to drop a row instead of a column.

# %%
Games.drop([0], axis=0, inplace=True)
Games.head()
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 1      22019  1611661319               LVA      Las Vegas Aces  1021900079
# 2      22019  1611661320               LAS  Los Angeles Sparks  1021900124
# 3      22019  1611661323               CON     Connecticut Sun  1021900122
# 4      22019  1611661317               PHO     Phoenix Mercury  1021900122
# 5      22019  1611661319               LVA      Las Vegas Aces  1021900124
#
#   GAME_DATE      MATCHUP   WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 1  8/5/2019  LVA vs. WAS  NaN  100   36  ...   0.800     5    10   15   12
# 2  8/1/2019  LAS vs. LVA    W  200   76  ...   1.000     5    28   33   19
# 3  8/1/2019  CON vs. PHO    W  200   68  ...   0.786    12    28   40   18
# 4  8/1/2019    PHO @ CON    L  199   62  ...   0.778     6    23   29   15
# 5  8/1/2019    LVA @ LAS    L  200   68  ...   0.765    10    29   39   17
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 1    2    0    7   8       -11.8
# 2    7    7   12  18         8.0
# 3   13    0   16  15         6.0
# 4    8    9   18  11        -6.0
# 5    7    4   14  13        -8.0
#
# [5 rows x 28 columns]

# %% [markdown]
# #### More often, we will drop observations based on certain conditions.
#
# For example, Las Vegas Aces is a women’s basketball team. If we are only going to focus on men’s basketball games, we will drop all the games played by Las Vegas Aces. In this case, we don’t have to use the “drop” function. We can specify our TEAM_NAME variables to be not equal to “Las Vegas Aces.”

# %%
Games=Games[Games.TEAM_NAME !="Las Vegas Aces"]
Games.head()
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 2      22019  1611661320               LAS  Los Angeles Sparks  1021900124
# 3      22019  1611661323               CON     Connecticut Sun  1021900122
# 4      22019  1611661317               PHO     Phoenix Mercury  1021900122
# 6      22019  1611661313               NYL    New York Liberty  1021900123
# 7      22019  1611661321               DAL        Dallas Wings  1021900123
#
#   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  STL  \
# 2  8/1/2019  LAS vs. LVA  W  200   76  ...   1.000     5    28   33   19    7
# 3  8/1/2019  CON vs. PHO  W  200   68  ...   0.786    12    28   40   18   13
# 4  8/1/2019    PHO @ CON  L  199   62  ...   0.778     6    23   29   15    8
# 6  8/1/2019    NYL @ DAL  L  200   64  ...   0.800     6    21   27   15   10
# 7  8/1/2019  DAL vs. NYL  W  200   87  ...   0.833     9    24   33   24   13
#
#    BLK  TOV  PF  PLUS_MINUS
# 2    7   12  18         8.0
# 3    0   16  15         6.0
# 4    9   18  11        -6.0
# 6    2   21  26       -23.0
# 7    6   18  21        23.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Self Test - 2
# - Drop all the Phoenix Mercury games

# %%
Games = Games[Games.TEAM_NAME !='Phoenix Mercury']
Games.head()
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 2      22019  1611661320               LAS  Los Angeles Sparks  1021900124
# 3      22019  1611661323               CON     Connecticut Sun  1021900122
# 6      22019  1611661313               NYL    New York Liberty  1021900123
# 7      22019  1611661321               DAL        Dallas Wings  1021900123
# 8      22019  1611661325               IND       Indiana Fever  1021900121
#
#    GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 2   8/1/2019  LAS vs. LVA  W  200   76  ...   1.000     5    28   33   19
# 3   8/1/2019  CON vs. PHO  W  200   68  ...   0.786    12    28   40   18
# 6   8/1/2019    NYL @ DAL  L  200   64  ...   0.800     6    21   27   15
# 7   8/1/2019  DAL vs. NYL  W  200   87  ...   0.833     9    24   33   24
# 8  7/31/2019  IND vs. ATL  W  200   61  ...   0.731     7    36   43   14
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 2    7    7   12  18         8.0
# 3   13    0   16  15         6.0
# 6   10    2   21  26       -23.0
# 7   13    6   18  21        23.0
# 8   11    4   15  17         2.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Merging Dataframes
#
# #### We will only focus on NBA games. We could merge the NBA_Teams and Games datasets to filter out NBA games.
#
# #### Teams are identified by the TEAM_ID. So, let’s merge the datasets by TEAM_ID. Since the variable “TEAM_NAME” is also present in both datasets, we could also include this variable as a criteria to merge the datasets so that in our new dataset, there is no duplicate variables.

# %%
NBA_Games=pd.merge(NBA_Teams, Games, on=['TEAM_ID', 'TEAM_NAME'])
NBA_Games.head()
# Out:
#   ABBREVIATION     CITY      TEAM_NAME     TEAM_ID NICKNAME    STATE  \
# 0          ATL  Atlanta  Atlanta Hawks  1610612737    Hawks  Atlanta
# 1          ATL  Atlanta  Atlanta Hawks  1610612737    Hawks  Atlanta
# 2          ATL  Atlanta  Atlanta Hawks  1610612737    Hawks  Atlanta
# 3          ATL  Atlanta  Atlanta Hawks  1610612737    Hawks  Atlanta
# 4          ATL  Atlanta  Atlanta Hawks  1610612737    Hawks  Atlanta
#
#    YEAR_FOUNDED  SEASON_ID TEAM_ABBREVIATION     GAME_ID  ... FT_PCT OREB  \
# 0          1949      22019               ATL  1521900072  ...  0.850   13
# 1          1949      22019               ATL  1521900060  ...  0.700    9
# 2          1949      22019               ATL  1521900042  ...  0.708    7
# 3          1949      22019               ATL  1521900023  ...  0.500    1
# 4          1949      22019               ATL  1521900023  ...  0.625    9
#
#   DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 0   23   36   14   15    3   12  24         8.0
# 1   28   37   19   10    8   22  25        -5.0
# 2   27   34   17    5    5   18  21        18.2
# 3    2    3    1    0    1    4   2         0.0
# 4   27   36    7    7   10   18  28       -24.0
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Understanding and cleaning the merged dataset
#
# _As you can tell, the merged dataset has a lot more variables and Python cannot fit all of them in the screen._
#
# #### We can obtain the list of variables using the “columns” command. This provides us a full list of variables in our dataset.

# %%
NBA_Games.columns
# Out:
# Index(['ABBREVIATION', 'CITY', 'TEAM_NAME', 'TEAM_ID', 'NICKNAME', 'STATE',
#        'YEAR_FOUNDED', 'SEASON_ID', 'TEAM_ABBREVIATION', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %% [markdown]
# #### Data Cleaning
# The variable “ABBREVIATION” AND “TEAM_ABBREVIATION” carry the same information and it is not necessary to keep both of them.
# - Delete "ABBREVIATION"

# %%
NBA_Games.drop(['ABBREVIATION'], axis=1, inplace=True, errors='ignore')

# %% [markdown]
# ## Self Test - 3
# - Find the number of observations and the number of variables in the dataset

# %%
NBA_Games.shape
# Out:
# (18421, 32)

# %% [markdown]
# The merged dataset is sorted by the criteria we use to merge the datasets. Thus, the NBA_Games dataset is currently sorted by "TEAM_ID." We may be interested to sort the data by other criteria, for example, the date of the game.
#
# #### We can do so by using the “sort_values” option.
#
# In our dataset, "GAME_ID" is created based on the date of the game. We can sort the games by “GAME_ID” and display the 20 most recent games.

# %%
NBA_Games.sort_values(by=['GAME_ID'], ascending=[False]).head(20)
# Out:
#               CITY            TEAM_NAME     TEAM_ID   NICKNAME      STATE  \
# 13449  San Antonio    San Antonio Spurs  1610612759      Spurs      Texas
# 15445         Utah            Utah Jazz  1610612762       Jazz       Utah
# 1304     Cleveland  Cleveland Cavaliers  1610612739  Cavaliers       Ohio
# 16076      Memphis    Memphis Grizzlies  1610612763  Grizzlies  Tennessee
# 15446         Utah            Utah Jazz  1610612762       Jazz       Utah
# 1305     Cleveland  Cleveland Cavaliers  1610612739  Cavaliers       Ohio
# 13450  San Antonio    San Antonio Spurs  1610612759      Spurs      Texas
# 16077      Memphis    Memphis Grizzlies  1610612763  Grizzlies  Tennessee
# 15447         Utah            Utah Jazz  1610612762       Jazz       Utah
# 16078      Memphis    Memphis Grizzlies  1610612763  Grizzlies  Tennessee
# 1306     Cleveland  Cleveland Cavaliers  1610612739  Cavaliers       Ohio
# 13451  San Antonio    San Antonio Spurs  1610612759      Spurs      Texas
# 15545         Utah            Utah Jazz  1610612762       Jazz       Utah
# 99         Atlanta        Atlanta Hawks  1610612737      Hawks    Atlanta
# 16173      Memphis    Memphis Grizzlies  1610612763  Grizzlies  Tennessee
# 13551  San Antonio    San Antonio Spurs  1610612759      Spurs      Texas
# 15546         Utah            Utah Jazz  1610612762       Jazz       Utah
# 16174      Memphis    Memphis Grizzlies  1610612763  Grizzlies  Tennessee
# 13552  San Antonio    San Antonio Spurs  1610612759      Spurs      Texas
# 100        Atlanta        Atlanta Hawks  1610612737      Hawks    Atlanta
#
#        YEAR_FOUNDED  SEASON_ID TEAM_ABBREVIATION     GAME_ID GAME_DATE  ...  \
# 13449          1976      22019               SAS  1621900006  7/3/2019  ...
# 15445          1974      22019               UTA  1621900006  7/3/2019  ...
# 1304           1970      22019               CLE  1621900005  7/3/2019  ...
# 16076          1995      22019               MEM  1621900005  7/3/2019  ...
# 15446          1974      22019               UTA  1621900004  7/2/2019  ...
# 1305           1970      22019               CLE  1621900004  7/2/2019  ...
# 13450          1976      22019               SAS  1621900003  7/2/2019  ...
# 16077          1995      22019               MEM  1621900003  7/2/2019  ...
# 15447          1974      22019               UTA  1621900002  7/1/2019  ...
# 16078          1995      22019               MEM  1621900002  7/1/2019  ...
# 1306           1970      22019               CLE  1621900001  7/1/2019  ...
# 13451          1976      22019               SAS  1621900001  7/1/2019  ...
# 15545          1974      22018               UTA  1621800006  7/5/2018  ...
# 99             1949      22018               ATL  1621800006  7/5/2018  ...
# 16173          1995      22018               MEM  1621800005  7/5/2018  ...
# 13551          1976      22018               SAS  1621800005  7/5/2018  ...
# 15546          1974      22018               UTA  1621800004  7/3/2018  ...
# 16174          1995      22018               MEM  1621800004  7/3/2018  ...
# 13552          1976      22018               SAS  1621800003  7/3/2018  ...
# 100            1949      22018               ATL  1621800003  7/3/2018  ...
#
#       FT_PCT OREB  DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 13449  0.615    9    29   38   12    5    3   11  14        -7.2
# 15445  0.684   13    31   44   15    6    5   15  25         5.8
# 1304   0.737    3    26   29   15    9    3   17  12       -13.0
# 16076  0.692   11    36   47   19    8    5   14  19        13.0
# 15446  0.750   11    34   45   18    3    4   14  18        14.6
# 1305   0.682    6    27   33   13    6    0    6  14       -15.0
# 13450  0.870   10    35   45   24   10    7   18  24        16.6
# 16077  0.867   10    29   39   17    6    5   17  18       -15.8
# 15447  0.462   14    27   41   16   10    7   19  26        -6.6
# 16078  0.704    8    32   40   14   14    4   20  19         7.4
# 1306   0.667   14    17   31   22   11    3   14  26        -8.0
# 13451  0.706    5    26   31   18    8    2   22  15         7.0
# 15545  0.633    8    36   44   21   11    7   19  25        -1.4
# 99     0.654   15    33   48   16   11    5   17  25         2.2
# 16173  0.706    6    26   32   16    7    6   11  24        -3.2
# 13551  0.682    6    29   35   20    6    2   14  13         3.2
# 15546  0.773    8    35   43   19    4    3   15  23        -7.0
# 16174  0.733    9    27   36   18    5    4    5  17         8.4
# 13552  0.786    6    45   51   24    9   10   17  23        25.8
# 100    0.545   14    29   43   12    9    2   12  25       -26.2
#
# [20 rows x 32 columns]

# %% [markdown]
# ## Missing Values
#
# ### Before we move on to doing any data analyses, we usually need to check if there is any missing value, that is, the source may have failed to collect some information.
#
# #### We can use the info() command which will return the total number of observations that have real values. By looking at these total numbers, we can see if there is any variable with missing value.

# %%
NBA_Games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18421 entries, 0 to 18420
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CITY               18421 non-null  object
#  1   TEAM_NAME          18421 non-null  object
#  2   TEAM_ID            18421 non-null  int64
#  3   NICKNAME           18421 non-null  object
#  4   STATE              18421 non-null  object
#  5   YEAR_FOUNDED       18421 non-null  int64
#  6   SEASON_ID          18421 non-null  int64
#  7   TEAM_ABBREVIATION  18421 non-null  object
#  8   GAME_ID            18421 non-null  int64
#  9   GAME_DATE          18421 non-null  object
#  10  MATCHUP            18421 non-null  object
#  11  WL                 18414 non-null  object
#  12  MIN                18421 non-null  int64
#  13  PTS                18421 non-null  int64
#  14  FGM                18421 non-null  int64
#  15  FGA                18421 non-null  int64
#  16  FG_PCT             18419 non-null  float64
#  17  FG3M               18421 non-null  int64
#  18  FG3A               18421 non-null  int64
#  19  FG3_PCT            18418 non-null  float64
#  20  FTM                18421 non-null  int64
#  21  FTA                18421 non-null  int64
#  22  FT_PCT             18418 non-null  float64
#  23  OREB               18421 non-null  int64
#  24  DREB               18421 non-null  int64
#  25  REB                18421 non-null  int64
#  26  AST                18421 non-null  int64
#  27  STL                18421 non-null  int64
#  28  BLK                18421 non-null  int64
#  29  TOV                18421 non-null  int64
#  30  PF                 18421 non-null  int64
#  31  PLUS_MINUS         18421 non-null  float64
# dtypes: float64(4), int64(20), object(8)
# memory usage: 4.6+ MB

# %% [markdown]
# _The total number of rows is 18956, so there are missing values in variable WL, FG_PCT, FG3_PCT, and FT_PCT._
#
# #### Detecting missing values
# We can use the isnull() function and the notnull() function to detect where the missing values are.

# %%
NBA_Games.notnull()
# Out:
#        CITY  TEAM_NAME  TEAM_ID  NICKNAME  STATE  YEAR_FOUNDED  SEASON_ID  \
# 0      True       True     True      True   True          True       True
# 1      True       True     True      True   True          True       True
# 2      True       True     True      True   True          True       True
# 3      True       True     True      True   True          True       True
# 4      True       True     True      True   True          True       True
# ...     ...        ...      ...       ...    ...           ...        ...
# 18416  True       True     True      True   True          True       True
# 18417  True       True     True      True   True          True       True
# 18418  True       True     True      True   True          True       True
# 18419  True       True     True      True   True          True       True
# 18420  True       True     True      True   True          True       True
#
#        TEAM_ABBREVIATION  GAME_ID  GAME_DATE  ...  FT_PCT  OREB  DREB   REB  \
# 0                   True     True       True  ...    True  True  True  True
# 1                   True     True       True  ...    True  True  True  True
# 2                   True     True       True  ...    True  True  True  True
# 3                   True     True       True  ...    True  True  True  True
# 4                   True     True       True  ...    True  True  True  True
# ...                  ...      ...        ...  ...     ...   ...   ...   ...
# 18416               True     True       True  ...    True  True  True  True
# 18417               True     True       True  ...    True  True  True  True
# 18418               True     True       True  ...    True  True  True  True
# 18419               True     True       True  ...    True  True  True  True
# 18420               True     True       True  ...    True  True  True  True
#
#         AST   STL   BLK   TOV    PF  PLUS_MINUS
# 0      True  True  True  True  True        True
# 1      True  True  True  True  True        True
# 2      True  True  True  True  True        True
# 3      True  True  True  True  True        True
# 4      True  True  True  True  True        True
# ...     ...   ...   ...   ...   ...         ...
# 18416  True  True  True  True  True        True
# 18417  True  True  True  True  True        True
# 18418  True  True  True  True  True        True
# 18419  True  True  True  True  True        True
# 18420  True  True  True  True  True        True
#
# [18421 rows x 32 columns]

# %% [markdown]
# ### Handling Missing Values
#
# There are two main approaches to handle missing values.
# - First, we can simply drop the observations with missing value.
#
# #### Drop observations with missing value in the variable "FG_PCT"

# %%
NBA_Games=NBA_Games[pd.notnull(NBA_Games["FG_PCT"])]
NBA_Games.shape
# Out:
# (18419, 32)

# %% [markdown]
# - Second, we can replace the missing values with valid values (Imputation), such as mean and median.
#
# #### We can use the fillna() command to replace missing values with the mean or the median of the variable.

# %%
NBA_Games=NBA_Games.fillna(NBA_Games.mean())
NBA_Games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18419 entries, 0 to 18420
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CITY               18419 non-null  object
#  1   TEAM_NAME          18419 non-null  object
#  2   TEAM_ID            18419 non-null  int64
#  3   NICKNAME           18419 non-null  object
#  4   STATE              18419 non-null  object
#  5   YEAR_FOUNDED       18419 non-null  int64
#  6   SEASON_ID          18419 non-null  int64
#  7   TEAM_ABBREVIATION  18419 non-null  object
#  8   GAME_ID            18419 non-null  int64
#  9   GAME_DATE          18419 non-null  object
#  10  MATCHUP            18419 non-null  object
#  11  WL                 18414 non-null  object
#  12  MIN                18419 non-null  int64
#  13  PTS                18419 non-null  int64
#  14  FGM                18419 non-null  int64
#  15  FGA                18419 non-null  int64
#  16  FG_PCT             18419 non-null  float64
#  17  FG3M               18419 non-null  int64
#  18  FG3A               18419 non-null  int64
#  19  FG3_PCT            18419 non-null  float64
#  20  FTM                18419 non-null  int64
#  21  FTA                18419 non-null  int64
#  22  FT_PCT             18419 non-null  float64
#  23  OREB               18419 non-null  int64
#  24  DREB               18419 non-null  int64
#  25  REB                18419 non-null  int64
#  26  AST                18419 non-null  int64
#  27  STL                18419 non-null  int64
#  28  BLK                18419 non-null  int64
#  29  TOV                18419 non-null  int64
#  30  PF                 18419 non-null  int64
#  31  PLUS_MINUS         18419 non-null  float64
# dtypes: float64(4), int64(20), object(8)
# memory usage: 4.6+ MB
# <ipython-input-21-15e9391c5b24>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   NBA_Games=NBA_Games.fillna(NBA_Games.mean())

# %% [markdown]
# ## Creating variables
# We can create a variable equals to the total number of goals made.

# %%
NBA_Games['GM']=NBA_Games['FGM']+NBA_Games['FG3M']+NBA_Games['FTM']

# %% [markdown]
# ## Self Test - 4
# - Create a variable called "GA" equals to the total number of goals attempted.

# %%
NBA_Games['GA'] = NBA_Games['FGA'] + NBA_Games['FG3A'] + NBA_Games['FTA']

# %% [markdown]
# ### Create variables based on conditions
# - We can create a variable conditional on the value of another variable.
#
# For example, we can create a variable "RESULT" that equals to 1 if the team won the game and 0 otherwise. The result of the game can be captured in the points of the team receive, whether it was positive or negative.

# %%
NBA_Games['RESULT'] = np.where(NBA_Games['PLUS_MINUS']>0, 'W', 'L')

# %% [markdown]
# We will now drop this newly created "RESULT" variable.

# %%
NBA_Games.drop(['RESULT'], axis=1, inplace=True)

# %% [markdown]
# ### Create a variable within group
# In the dataset, each game has two observations, one represents the statistics of the home team, one represents those of the away team. Both observations have the same GAME_ID. We can create a variable "POINT_DIFF" that equals the difference between the points earned by the two teams.
#
# We will first sort the data not only by the "GAME_ID" but also by the result "WL".

# %%
NBA_Games.sort_values(['GAME_ID','WL'], inplace=True)
NBA_Games["POINT_DIFF"]=NBA_Games.groupby(["GAME_ID"])["PTS"].diff()

# %% [markdown]
# The "POINT_DIFF" variable only has the point difference for the winning team, we need to impute the point difference for the losing team as well.

# %%
NBA_Games['POINT_DIFF'] = NBA_Games['POINT_DIFF'].fillna(NBA_Games.groupby('GAME_ID')['POINT_DIFF'].transform('mean'))

# %% [markdown]
# - We can also drop all observations with missing value in at least one variable using the "dropna()" command.

# %%
NBA_Games=NBA_Games.dropna()
NBA_Games.shape
# Out:
# (17779, 34)

# %% [markdown]
# ### Creating new dataframe
#
# #### Create a new dataframe that aggregates information by group
#
# Sometimes we may want to work with season level data rather than team level data. We can create a new dataset that includes aggregate information of team statistics in each season.

# %%
NBA_Team_Stats=NBA_Games.groupby(['TEAM_ID', 'SEASON_ID'])['PTS','FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FT_PCT','OREB','DREB','REB','AST','STL','BLK','TOV','PF','PLUS_MINUS'].sum()
display(NBA_Team_Stats)
# Out:
# <ipython-input-28-4fe2096e04f0>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   NBA_Team_Stats=NBA_Games.groupby(['TEAM_ID', 'SEASON_ID'])['PTS','FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FT_PCT','OREB','DREB','REB','AST','STL','BLK','TOV','PF','PLUS_MINUS'].sum()
#                        PTS   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT   FTM  \
# TEAM_ID    SEASON_ID
# 1610612737 12013       523   193   459   2.520    34   131    1.576   103
#            12014       708   247   554   3.122    66   182    2.549   148
#            12015       652   226   548   2.896    59   176    2.340   141
#            12016       686   261   593   3.083    50   159    2.140   114
#            12017       480   167   410   2.045    51   156    1.611    95
# ...                    ...   ...   ...     ...   ...   ...      ...   ...
# 1610612766 22016      8709  3137  7121  37.089   822  2368   28.922  1613
#            22017      9088  3276  7272  38.326   829  2267   30.411  1707
#            22018      9290  3382  7569  38.038   984  2838   29.386  1542
#            22019       336   127   301   1.685    37   120    1.190    45
#            42015       632   223   563   2.782    40   130    2.056   146
#
#                        FTA  FT_PCT  OREB  DREB   REB   AST  STL  BLK   TOV  \
# TEAM_ID    SEASON_ID
# 1610612737 12013       140   4.477    44   184   228   130   61   22   118
#            12014       197   5.262    63   237   300   178   48   35   116
#            12015       175   5.630    53   271   324   141   57   41   122
#            12016       153   5.253    71   263   334   184   52   40   112
#            12017       125   3.798    40   169   209   113   40   15    95
# ...                    ...     ...   ...   ...   ...   ...  ...  ...   ...
# 1610612766 22016      1984  68.453   762  2899  3661  1904  585  413   935
#            22017      2280  63.732   856  2949  3805  1786  584  371  1046
#            22018      1941  67.302   846  2860  3706  1949  622  411  1010
#            22019        58   3.058    41   102   143    71   33   13    63
#            42015       174   6.000    50   208   258    95   40   23    58
#
#                         PF  PLUS_MINUS
# TEAM_ID    SEASON_ID
# 1610612737 12013       112       -75.0
#            12014       170        15.0
#            12015       143        -5.0
#            12016       154        41.0
#            12017        91       -17.6
# ...                    ...         ...
# 1610612766 22016      1394        30.0
#            22017      1475        31.0
#            22018      1597       -66.2
#            22019        83        13.2
#            42015       122       -62.0
#
# [515 rows x 19 columns]

# %% [markdown]
# Notice that the newly created dataset has two levels of index, the "TEAM_ID" and "SEASON_ID"
#
# #### If we want to convert these two indexes back as variables, we can use the "reset_index" command.

# %%
NBA_Team_Stats=NBA_Team_Stats.reset_index()
display(NBA_Team_Stats)
# Out:
#         TEAM_ID  SEASON_ID   PTS   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0    1610612737      12013   523   193   459   2.520    34   131    1.576
# 1    1610612737      12014   708   247   554   3.122    66   182    2.549
# 2    1610612737      12015   652   226   548   2.896    59   176    2.340
# 3    1610612737      12016   686   261   593   3.083    50   159    2.140
# 4    1610612737      12017   480   167   410   2.045    51   156    1.611
# ..          ...        ...   ...   ...   ...     ...   ...   ...      ...
# 510  1610612766      22016  8709  3137  7121  37.089   822  2368   28.922
# 511  1610612766      22017  9088  3276  7272  38.326   829  2267   30.411
# 512  1610612766      22018  9290  3382  7569  38.038   984  2838   29.386
# 513  1610612766      22019   336   127   301   1.685    37   120    1.190
# 514  1610612766      42015   632   223   563   2.782    40   130    2.056
#
#       FTM  ...  FT_PCT  OREB  DREB   REB   AST  STL  BLK   TOV    PF  \
# 0     103  ...   4.477    44   184   228   130   61   22   118   112
# 1     148  ...   5.262    63   237   300   178   48   35   116   170
# 2     141  ...   5.630    53   271   324   141   57   41   122   143
# 3     114  ...   5.253    71   263   334   184   52   40   112   154
# 4      95  ...   3.798    40   169   209   113   40   15    95    91
# ..    ...  ...     ...   ...   ...   ...   ...  ...  ...   ...   ...
# 510  1613  ...  68.453   762  2899  3661  1904  585  413   935  1394
# 511  1707  ...  63.732   856  2949  3805  1786  584  371  1046  1475
# 512  1542  ...  67.302   846  2860  3706  1949  622  411  1010  1597
# 513    45  ...   3.058    41   102   143    71   33   13    63    83
# 514   146  ...   6.000    50   208   258    95   40   23    58   122
#
#      PLUS_MINUS
# 0         -75.0
# 1          15.0
# 2          -5.0
# 3          41.0
# 4         -17.6
# ..          ...
# 510        30.0
# 511        31.0
# 512       -66.2
# 513        13.2
# 514       -62.0
#
# [515 rows x 21 columns]

# %% [markdown]
# ### We can create a variable that equals to the total number of observations within a specified group using the size() command.
# - Create a variable that equals to the total number of games played by a team in each season, name this variable "GAME_COUNT".

# %%
NBA_Game_Count=NBA_Games.groupby(['TEAM_ID','SEASON_ID']).size().reset_index(name='GAME_COUNT')
display(NBA_Game_Count)
# Out:
#         TEAM_ID  SEASON_ID  GAME_COUNT
# 0    1610612737      12013           6
# 1    1610612737      12014           7
# 2    1610612737      12015           7
# 3    1610612737      12016           7
# 4    1610612737      12017           5
# ..          ...        ...         ...
# 510  1610612766      22016          84
# 511  1610612766      22017          85
# 512  1610612766      22018          85
# 513  1610612766      22019           4
# 514  1610612766      42015           7
#
# [515 rows x 3 columns]

# %% [markdown]
# ## Saving data
#
# ### We can save a dataframe by exporting the edited dataframe to csv file using the “to_csv” command.
# - Save merged data as a csv file
# _We can use the "index=False" command to save the data without adding the index as a column in the csv file_

# %%
NBA_Games.to_csv("../../Data/Week 2/NBA_Games.csv", index=False)
